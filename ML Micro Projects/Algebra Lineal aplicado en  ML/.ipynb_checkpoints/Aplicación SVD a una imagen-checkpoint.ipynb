# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
plt.style.use('classic')

imagen = Image.open("imagenes/imagen_ejemplo_frida_bredesen.jpg")

plt.imshow(imagen)

# %%
imagen_gr = imagen.convert('LA')
print(image_gr)
# Out:
# <PIL.Image.Image image mode=LA size=3693x3456 at 0x1B0B6716160>

# %%
imagen_mat = np.array(list(imagen_gr.getdata(band=0)), float)
print(imagen_mat)
# Out:
# [236. 236. 235. ... 195. 195. 193.]

# %%
imagen_mat.shape = (imagen_gr.size[1], imagen_gr.size[0])
print(imagen_mat)
# Out:
# [[236. 236. 235. ... 239. 239. 239.]
#  [236. 236. 235. ... 239. 239. 239.]
#  [236. 236. 235. ... 238. 238. 238.]
#  ...
#  [217. 216. 216. ... 197. 196. 194.]
#  [216. 216. 216. ... 196. 195. 193.]
#  [216. 216. 216. ... 195. 195. 193.]]

# %%
print(imagen_mat.shape)
# Out:
# (3456, 3693)

# %%
plt.imshow(imagen_mat, cmap = 'gray')
plt.show()

# %%
imagen_mat_2 = imagen_mat /255
print(imagen_mat_2)
# Out:
# [[0.9254902  0.9254902  0.92156863 ... 0.9372549  0.9372549  0.9372549 ]
#  [0.9254902  0.9254902  0.92156863 ... 0.9372549  0.9372549  0.9372549 ]
#  [0.9254902  0.9254902  0.92156863 ... 0.93333333 0.93333333 0.93333333]
#  ...
#  [0.85098039 0.84705882 0.84705882 ... 0.77254902 0.76862745 0.76078431]
#  [0.84705882 0.84705882 0.84705882 ... 0.76862745 0.76470588 0.75686275]
#  [0.84705882 0.84705882 0.84705882 ... 0.76470588 0.76470588 0.75686275]]

# %%
plt.imshow(imagen_mat_2)
plt.show()

# %%
plt.imshow(imagen_mat_2, cmap ="gray")
plt.show()

# %% [markdown]
# # Descomposición SVD a  una matriz

# %%
U, D, V = np.linalg.svd(imagen_mat)

# %%
print(imagen_mat.shape)
print(U.shape)
print(D.shape)
print(V.shape)
# Out:
# (3456, 3693)
# (3456, 3456)
# (3456,)
# (3693, 3693)

# %%
imagen_recons = np.matrix(U[:, :1]) * np.diag(D[:1]) * np.matrix(V[:1, :])
plt.imshow(imagen_recons, cmap = 'gray')

# %%
i = 5 
imagen_recons = np.matrix(U[:, :i]) * np.diag(D[:i]) * np.matrix(V[:i, :])
plt.imshow(imagen_recons, cmap = 'gray')

title = "valores singulares = %s"%i

plt.title(title)
plt.show()

# %%
i = 10 
imagen_recons = np.matrix(U[:, :i]) * np.diag(D[:i]) * np.matrix(V[:i, :])
plt.imshow(imagen_recons, cmap = 'gray')

title = "valores singulares = %s"%i

plt.title(title)
plt.show()

# %%
i = 25 
imagen_recons = np.matrix(U[:, :i]) * np.diag(D[:i]) * np.matrix(V[:i, :])
plt.imshow(imagen_recons, cmap = 'gray')

title = "valores singulares = %s"%i

plt.title(title)
plt.show()

# %%
i = 50
imagen_recons = np.matrix(U[:, :i]) * np.diag(D[:i]) * np.matrix(V[:i, :])
plt.imshow(imagen_recons, cmap = 'gray')

title = "valores singulares = %s"%i

plt.title(title)
plt.show()
